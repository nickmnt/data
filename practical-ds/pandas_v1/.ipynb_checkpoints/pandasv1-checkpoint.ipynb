# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
pd.options.display.min_rows = 10

# %%
pd.options.display.max_rows = 60

# %%
# Experiment with min_rows = None and max = 600
# then print titanic

# %% [markdown]
# ## Info() method - extended output

# %%
players = pd.read_csv('players.csv', index_col="Player")

# %%
players
# Out:
#                   Nationality          Club  World_Champion  Height  \
# Player
# Lionel Messi        Argentina  FC Barcelona           False    1.70
# Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# Neymar Junior          Brasil      Paris SG           False    1.75
# Kylian Mbappe          France      Paris SG            True    1.78
# Manuel Neuer          Germany     FC Bayern            True    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45          51  False
# Cristiano Ronaldo          44          28     No
# Neymar Junior              28          23    NaN
# Kylian Mbappe              21          39   True
# Manuel Neuer                0           0   2014

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Lionel Messi to Manuel Neuer
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nationality     5 non-null      object
#  1   Club            5 non-null      object
#  2   World_Champion  5 non-null      bool
#  3   Height          5 non-null      float64
#  4   Goals_2018      5 non-null      int64
#  5   Goals_2019      5 non-null      int64
#  6   WC              4 non-null      object
# dtypes: bool(1), float64(1), int64(2), object(3)
# memory usage: 285.0+ bytes

# %% [markdown]
# ## New extension dtypes ("nullable" dtypes)

# %%
import numpy as np

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Lionel Messi to Manuel Neuer
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nationality     5 non-null      object
#  1   Club            5 non-null      object
#  2   World_Champion  5 non-null      bool
#  3   Height          5 non-null      float64
#  4   Goals_2018      5 non-null      int64
#  5   Goals_2019      5 non-null      int64
#  6   WC              4 non-null      object
# dtypes: bool(1), float64(1), int64(2), object(3)
# memory usage: 285.0+ bytes

# %%
players2 = pd.read_csv('players2.csv', index_col="Player")

# %%
players2
# Out:
#                   Nationality          Club World_Champion  Height  \
# Player
# Lionel Messi        Argentina  FC Barcelona          False     NaN
# Cristiano Ronaldo         NaN   Juventus FC          False    1.87
# Neymar Junior          Brasil      Paris SG          False    1.75
# Kylian Mbappe          France           NaN           True    1.78
# Manuel Neuer          Germany     FC Bayern            NaN    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45        51.0  False
# Cristiano Ronaldo          44        28.0     No
# Neymar Junior              28         NaN    NaN
# Kylian Mbappe              21        39.0   True
# Manuel Neuer                0         0.0   2014

# %%
players2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Lionel Messi to Manuel Neuer
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nationality     4 non-null      object
#  1   Club            4 non-null      object
#  2   World_Champion  4 non-null      object
#  3   Height          4 non-null      float64
#  4   Goals_2018      5 non-null      int64
#  5   Goals_2019      4 non-null      float64
#  6   WC              4 non-null      object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 320.0+ bytes

# %% [markdown]
# ## Creating the new extension dtypes with convert_dtypes()

# %%
players2
# Out:
#                   Nationality          Club World_Champion  Height  \
# Player
# Lionel Messi        Argentina  FC Barcelona          False     NaN
# Cristiano Ronaldo         NaN   Juventus FC          False    1.87
# Neymar Junior          Brasil      Paris SG          False    1.75
# Kylian Mbappe          France           NaN           True    1.78
# Manuel Neuer          Germany     FC Bayern            NaN    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45        51.0  False
# Cristiano Ronaldo          44        28.0     No
# Neymar Junior              28         NaN    NaN
# Kylian Mbappe              21        39.0   True
# Manuel Neuer                0         0.0   2014

# %%
players2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Lionel Messi to Manuel Neuer
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nationality     4 non-null      object
#  1   Club            4 non-null      object
#  2   World_Champion  4 non-null      object
#  3   Height          4 non-null      float64
#  4   Goals_2018      5 non-null      int64
#  5   Goals_2019      4 non-null      float64
#  6   WC              4 non-null      object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 320.0+ bytes

# %%
players3 = players2.convert_dtypes()

# %%
players3
# Out:
#                   Nationality          Club  World_Champion  Height  \
# Player
# Lionel Messi        Argentina  FC Barcelona           False    <NA>
# Cristiano Ronaldo        <NA>   Juventus FC           False    1.87
# Neymar Junior          Brasil      Paris SG           False    1.75
# Kylian Mbappe          France          <NA>            True    1.78
# Manuel Neuer          Germany     FC Bayern            <NA>    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45          51  False
# Cristiano Ronaldo          44          28     No
# Neymar Junior              28        <NA>   <NA>
# Kylian Mbappe              21          39   True
# Manuel Neuer                0           0   2014

# %%
players3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Lionel Messi to Manuel Neuer
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nationality     4 non-null      string
#  1   Club            4 non-null      string
#  2   World_Champion  4 non-null      boolean
#  3   Height          4 non-null      Float64
#  4   Goals_2018      5 non-null      Int64
#  5   Goals_2019      4 non-null      Int64
#  6   WC              4 non-null      string
# dtypes: Float64(1), Int64(2), boolean(1), string(3)
# memory usage: 305.0+ bytes

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Lionel Messi to Manuel Neuer
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nationality     5 non-null      object
#  1   Club            5 non-null      object
#  2   World_Champion  5 non-null      bool
#  3   Height          5 non-null      float64
#  4   Goals_2018      5 non-null      int64
#  5   Goals_2019      5 non-null      int64
#  6   WC              4 non-null      object
# dtypes: bool(1), float64(1), int64(2), object(3)
# memory usage: 285.0+ bytes

# %% [markdown]
# ## New pd.NA for missing values

# %%
players2
# Out:
#                   Nationality          Club World_Champion  Height  \
# Player
# Lionel Messi        Argentina  FC Barcelona          False     NaN
# Cristiano Ronaldo         NaN   Juventus FC          False    1.87
# Neymar Junior          Brasil      Paris SG          False    1.75
# Kylian Mbappe          France           NaN           True    1.78
# Manuel Neuer          Germany     FC Bayern            NaN    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45        51.0  False
# Cristiano Ronaldo          44        28.0     No
# Neymar Junior              28         NaN    NaN
# Kylian Mbappe              21        39.0   True
# Manuel Neuer                0         0.0   2014

# %%
players2.loc['Cristiano Ronaldo', 'Nationality']
# Out:
# nan

# %%
np.nan
# Out:
# nan

# %%
players3
# Out:
#                   Nationality          Club  World_Champion  Height  \
# Player
# Lionel Messi        Argentina  FC Barcelona           False    <NA>
# Cristiano Ronaldo        <NA>   Juventus FC           False    1.87
# Neymar Junior          Brasil      Paris SG           False    1.75
# Kylian Mbappe          France          <NA>            True    1.78
# Manuel Neuer          Germany     FC Bayern            <NA>    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45          51  False
# Cristiano Ronaldo          44          28     No
# Neymar Junior              28        <NA>   <NA>
# Kylian Mbappe              21          39   True
# Manuel Neuer                0           0   2014

# %%
players3.loc['Cristiano Ronaldo', 'Nationality']

# %%
type(players3.loc['Cristiano Ronaldo', 'Nationality'])
# Out:
# pandas._libs.missing.NAType

# %%
pd.NA

# %%
players3.iloc[0, 0] = pd.NA

# %%
players3
# Out:
#                   Nationality          Club  World_Champion  Height  \
# Player
# Lionel Messi             <NA>  FC Barcelona           False    <NA>
# Cristiano Ronaldo        <NA>   Juventus FC           False    1.87
# Neymar Junior          Brasil      Paris SG           False    1.75
# Kylian Mbappe          France          <NA>            True    1.78
# Manuel Neuer          Germany     FC Bayern            <NA>    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45          51  False
# Cristiano Ronaldo          44          28     No
# Neymar Junior              28        <NA>   <NA>
# Kylian Mbappe              21          39   True
# Manuel Neuer                0           0   2014

# %%
pd.NA + 1

# %%
np.nan + 1
# Out:
# nan

# %%
pd.NA > 1

# %%
np.nan > 1
# Out:
# False

# %%
pd.NA & True

# %%
pd.NA & False
# Out:
# False

# %%
pd.NA | True
# Out:
# True

# %%
pd.NA | False

# %%
players3.isnull()
# Out:
#                    Nationality   Club  World_Champion  Height  Goals_2018  \
# Player
# Lionel Messi              True  False           False    True       False
# Cristiano Ronaldo         True  False           False   False       False
# Neymar Junior            False  False           False   False       False
# Kylian Mbappe            False   True           False   False       False
# Manuel Neuer             False  False            True   False       False
#
#                    Goals_2019     WC
# Player
# Lionel Messi            False  False
# Cristiano Ronaldo       False  False
# Neymar Junior            True   True
# Kylian Mbappe           False  False
# Manuel Neuer            False  False

# %% [markdown]
# ## New nullable Int64Dtype

# %%
players3
# Out:
#                   Nationality          Club  World_Champion  Height  \
# Player
# Lionel Messi             <NA>  FC Barcelona           False    <NA>
# Cristiano Ronaldo        <NA>   Juventus FC           False    1.87
# Neymar Junior          Brasil      Paris SG           False    1.75
# Kylian Mbappe          France          <NA>            True    1.78
# Manuel Neuer          Germany     FC Bayern            <NA>    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45          51  False
# Cristiano Ronaldo          44          28     No
# Neymar Junior              28        <NA>   <NA>
# Kylian Mbappe              21          39   True
# Manuel Neuer                0           0   2014

# %%
s = pd.Series([1, 2, None], dtype='Int64')
s
# Out:
# 0       1
# 1       2
# 2    <NA>
# dtype: Int64

# %%
players2.Goals_2019.astype('Int64')
# Out:
# Player
# Lionel Messi           51
# Cristiano Ronaldo      28
# Neymar Junior        <NA>
# Kylian Mbappe          39
# Manuel Neuer            0
# Name: Goals_2019, dtype: Int64

# %%
players3.select_dtypes(include="Int64")
# Out:
#                    Goals_2018  Goals_2019
# Player
# Lionel Messi               45          51
# Cristiano Ronaldo          44          28
# Neymar Junior              28        <NA>
# Kylian Mbappe              21          39
# Manuel Neuer                0           0

# %%
players2
# Out:
#                   Nationality          Club World_Champion  Height  \
# Player
# Lionel Messi        Argentina  FC Barcelona          False     NaN
# Cristiano Ronaldo         NaN   Juventus FC          False    1.87
# Neymar Junior          Brasil      Paris SG          False    1.75
# Kylian Mbappe          France           NaN           True    1.78
# Manuel Neuer          Germany     FC Bayern            NaN    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45        51.0  False
# Cristiano Ronaldo          44        28.0     No
# Neymar Junior              28         NaN    NaN
# Kylian Mbappe              21        39.0   True
# Manuel Neuer                0         0.0   2014

# %%
players2.Goals_2019 > 20
# Out:
# Player
# Lionel Messi          True
# Cristiano Ronaldo     True
# Neymar Junior        False
# Kylian Mbappe         True
# Manuel Neuer         False
# Name: Goals_2019, dtype: bool

# %%
players3.Goals_2019 > 20
# Out:
# Player
# Lionel Messi          True
# Cristiano Ronaldo     True
# Neymar Junior         <NA>
# Kylian Mbappe         True
# Manuel Neuer         False
# Name: Goals_2019, dtype: boolean

# %% [markdown]
# ## New "nullable" BooleanDtype

# %%
players3
# Out:
#                   Nationality          Club  World_Champion  Height  \
# Player
# Lionel Messi             <NA>  FC Barcelona           False    <NA>
# Cristiano Ronaldo        <NA>   Juventus FC           False    1.87
# Neymar Junior          Brasil      Paris SG           False    1.75
# Kylian Mbappe          France          <NA>            True    1.78
# Manuel Neuer          Germany     FC Bayern            <NA>    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45          51  False
# Cristiano Ronaldo          44          28     No
# Neymar Junior              28        <NA>   <NA>
# Kylian Mbappe              21          39   True
# Manuel Neuer                0           0   2014

# %%
players3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Lionel Messi to Manuel Neuer
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nationality     3 non-null      string
#  1   Club            4 non-null      string
#  2   World_Champion  4 non-null      boolean
#  3   Height          4 non-null      Float64
#  4   Goals_2018      5 non-null      Int64
#  5   Goals_2019      4 non-null      Int64
#  6   WC              4 non-null      string
# dtypes: Float64(1), Int64(2), boolean(1), string(3)
# memory usage: 477.0+ bytes

# %%
s = pd.Series([True, False, None], dtype="boolean")
s
# Out:
# 0     True
# 1    False
# 2     <NA>
# dtype: boolean

# %%
players2.World_Champion.astype("boolean")
# Out:
# Player
# Lionel Messi         False
# Cristiano Ronaldo    False
# Neymar Junior        False
# Kylian Mbappe         True
# Manuel Neuer          <NA>
# Name: World_Champion, dtype: boolean

# %%
players3.select_dtypes(include="boolean")
# Out:
#                    World_Champion
# Player
# Lionel Messi                False
# Cristiano Ronaldo           False
# Neymar Junior               False
# Kylian Mbappe                True
# Manuel Neuer                 <NA>

# %%
players2
# Out:
#                   Nationality          Club World_Champion  Height  \
# Player
# Lionel Messi        Argentina  FC Barcelona          False     NaN
# Cristiano Ronaldo         NaN   Juventus FC          False    1.87
# Neymar Junior          Brasil      Paris SG          False    1.75
# Kylian Mbappe          France           NaN           True    1.78
# Manuel Neuer          Germany     FC Bayern            NaN    1.93
#
#                    Goals_2018  Goals_2019     WC
# Player
# Lionel Messi               45        51.0  False
# Cristiano Ronaldo          44        28.0     No
# Neymar Junior              28         NaN    NaN
# Kylian Mbappe              21        39.0   True
# Manuel Neuer                0         0.0   2014

# %%
cl = [True, True, True, False, True]
cl
# Out:
# [True, True, True, False, True]

# %%
players2.World_Champion | cl
# Out:
# Player
# Lionel Messi          True
# Cristiano Ronaldo     True
# Neymar Junior         True
# Kylian Mbappe         True
# Manuel Neuer         False
# Name: World_Champion, dtype: bool

# %%
players3.World_Champion | cl # Obviously improved (Last item should be True)
# Out:
# Player
# Lionel Messi         True
# Cristiano Ronaldo    True
# Neymar Junior        True
# Kylian Mbappe        True
# Manuel Neuer         True
# Name: World_Champion, dtype: boolean

# %% [markdown]
# ## Addition of the ignore_index parameter

# %%
import pandas as pd

# %%
players = pd.read_csv("players.csv")

# %%
players
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 0       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 2      Neymar Junior      Brasil      Paris SG           False    1.75
# 3      Kylian Mbappe      France      Paris SG            True    1.78
# 4       Manuel Neuer     Germany     FC Bayern            True    1.93
#
#    Goals_2018  Goals_2019     WC
# 0          45          51  False
# 1          44          28     No
# 2          28          23    NaN
# 3          21          39   True
# 4           0           0   2014

# %%
players.sort_values(by="Height", ascending=False)
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 4       Manuel Neuer     Germany     FC Bayern            True    1.93
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 3      Kylian Mbappe      France      Paris SG            True    1.78
# 2      Neymar Junior      Brasil      Paris SG           False    1.75
# 0       Lionel Messi   Argentina  FC Barcelona           False    1.70
#
#    Goals_2018  Goals_2019     WC
# 4           0           0   2014
# 1          44          28     No
# 3          21          39   True
# 2          28          23    NaN
# 0          45          51  False

# %%
players.sort_values(by="Height", ascending=False).reset_index(drop=True) # Old way
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 0       Manuel Neuer     Germany     FC Bayern            True    1.93
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 2      Kylian Mbappe      France      Paris SG            True    1.78
# 3      Neymar Junior      Brasil      Paris SG           False    1.75
# 4       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 5       Lionel Messi   Argentina  FC Barcelona           False    1.70
#
#    Goals_2018  Goals_2019     WC
# 0           0           0   2014
# 1          44          28     No
# 2          21          39   True
# 3          28          23    NaN
# 4          45          51  False
# 5          45          51  False

# %%
players.sort_values(by="Height", ascending=False, ignore_index=True) # New way
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 0       Manuel Neuer     Germany     FC Bayern            True    1.93
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 2      Kylian Mbappe      France      Paris SG            True    1.78
# 3      Neymar Junior      Brasil      Paris SG           False    1.75
# 4       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 5       Lionel Messi   Argentina  FC Barcelona           False    1.70
#
#    Goals_2018  Goals_2019     WC
# 0           0           0   2014
# 1          44          28     No
# 2          21          39   True
# 3          28          23    NaN
# 4          45          51  False
# 5          45          51  False

# %%
players = pd.read_csv("players3.csv")

# %%
players
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 0       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 2       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 3      Neymar Junior      Brasil      Paris SG           False    1.75
# 4      Kylian Mbappe      France      Paris SG            True    1.78
# 5       Manuel Neuer     Germany     FC Bayern            True    1.93
#
#    Goals_2018  Goals_2019     WC
# 0          45          51  False
# 1          44          28     No
# 2          45          51  False
# 3          28          23    NaN
# 4          21          39   True
# 5           0           0   2014

# %%
players.sort_values(by="Height", ascending=False)
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 5       Manuel Neuer     Germany     FC Bayern            True    1.93
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 4      Kylian Mbappe      France      Paris SG            True    1.78
# 3      Neymar Junior      Brasil      Paris SG           False    1.75
# 0       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 2       Lionel Messi   Argentina  FC Barcelona           False    1.70
#
#    Goals_2018  Goals_2019     WC
# 5           0           0   2014
# 1          44          28     No
# 4          21          39   True
# 3          28          23    NaN
# 0          45          51  False
# 2          45          51  False

# %%
players.drop_duplicates()
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 0       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 3      Neymar Junior      Brasil      Paris SG           False    1.75
# 4      Kylian Mbappe      France      Paris SG            True    1.78
# 5       Manuel Neuer     Germany     FC Bayern            True    1.93
#
#    Goals_2018  Goals_2019     WC
# 0          45          51  False
# 1          44          28     No
# 3          28          23    NaN
# 4          21          39   True
# 5           0           0   2014

# %%
players.drop_duplicates(ignore_index=True)
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 0       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 2      Neymar Junior      Brasil      Paris SG           False    1.75
# 3      Kylian Mbappe      France      Paris SG            True    1.78
# 4       Manuel Neuer     Germany     FC Bayern            True    1.93
#
#    Goals_2018  Goals_2019     WC
# 0          45          51  False
# 1          44          28     No
# 2          28          23    NaN
# 3          21          39   True
# 4           0           0   2014

# %% [markdown]
# ## Removal of prior version deprecations

# %% [markdown]
# > ix is deprecated
#
# > players.loc[["Lionel Messi", "Donald Duck"]] worked in the past but doesn't now
# > reindex is used now, reindex only works with a unique index
#
# > ptp is deprecated, use x.max() - x.min() instead, you can also use np.ptp
