# %%
import pandas as pd

# %%
df = pd.read_csv('us_baby_names.csv')

# %%
df
# Out:
#          Year       Name Gender  Count
# 0        1880       Mary      F   7065
# 1        1880       Anna      F   2604
# 2        1880       Emma      F   2003
# 3        1880  Elizabeth      F   1939
# 4        1880     Minnie      F   1746
# ...       ...        ...    ...    ...
# 1957041  2018      Zylas      M      5
# 1957042  2018      Zyran      M      5
# 1957043  2018      Zyrie      M      5
# 1957044  2018      Zyron      M      5
# 1957045  2018      Zzyzx      M      5
#
# [1957046 rows x 4 columns]

# %%
df.nunique()
# Out:
# Year        139
# Name      98400
# Gender        2
# Count     13720
# dtype: int64

# %%
df[(df['Year'] == 2018) & (df['Gender'] == 'F')]
# Out:
#          Year      Name Gender  Count
# 1925013  2018      Emma      F  18688
# 1925014  2018    Olivia      F  17921
# 1925015  2018       Ava      F  14924
# 1925016  2018  Isabella      F  14464
# 1925017  2018    Sophia      F  13928
# ...       ...       ...    ...    ...
# 1943037  2018   Zymirah      F      5
# 1943038  2018     Zynah      F      5
# 1943039  2018   Zyniyah      F      5
# 1943040  2018    Zynlee      F      5
# 1943041  2018     Zyona      F      5
#
# [18029 rows x 4 columns]

# %% [markdown]
# Find the most popular __Baby Girl Names__ in __2018__.

# %%
df[(df["Year"] == 2018) & (df['Gender'] == 'F')].nlargest(10, 'Count')
# Out:
#          Year       Name Gender  Count
# 1925013  2018       Emma      F  18688
# 1925014  2018     Olivia      F  17921
# 1925015  2018        Ava      F  14924
# 1925016  2018   Isabella      F  14464
# 1925017  2018     Sophia      F  13928
# 1925018  2018  Charlotte      F  12940
# 1925019  2018        Mia      F  12642
# 1925020  2018     Amelia      F  12301
# 1925021  2018     Harper      F  10582
# 1925022  2018     Evelyn      F  10376

# %% [markdown]
# Find the most popular __Baby Boy Names__ in __2018__.

# %%
df[(df["Year"] == 2018) & (df['Gender'] == 'M')].nlargest(10, 'Count')
# Out:
#          Year      Name Gender  Count
# 1943042  2018      Liam      M  19837
# 1943043  2018      Noah      M  18267
# 1943044  2018   William      M  14516
# 1943045  2018     James      M  13525
# 1943046  2018    Oliver      M  13389
# 1943047  2018  Benjamin      M  13381
# 1943048  2018    Elijah      M  12886
# 1943049  2018     Lucas      M  12585
# 1943050  2018     Mason      M  12435
# 1943051  2018     Logan      M  12352

# %% [markdown]
# __Create__ the function __most_pop(year, gender, n)__ that returns the __n__ most popular __M/F__ Names in the __year XYZ__.

# %%
def most_pop(year, gender, n):
    return df[(df['Year'] == year) & (df['Gender'] == gender)].nlargest(n, 'Count')

most_pop(2017, 'M', 10)
# Out:
#          Year      Name Gender  Count  Popularity  Rank
# 1910798  2017      Liam      M  18798       10200   1.0
# 1910799  2017      Noah      M  18410        9990   2.0
# 1910800  2017   William      M  14967        8121   3.0
# 1910801  2017     James      M  14291        7754   4.0
# 1910802  2017     Logan      M  14014        7604   5.0
# 1910803  2017  Benjamin      M  13797        7486   6.0
# 1910804  2017     Mason      M  13549        7352   7.0
# 1910805  2017    Elijah      M  13344        7241   8.0
# 1910806  2017    Oliver      M  13193        7159   9.0
# 1910807  2017     Jacob      M  13178        7150  10.0

# %% [markdown]
# ## Evergreen Names (1880 - 2018)

# %% [markdown]
# Find those __Evergreen Boy Names__ that are in __1880 and 2018__ among the most popular Boy Names (__Top 20__).

# %%
df_1880 = most_pop(1880, 'M', 20)
df_1880
# Out:
#      Year     Name Gender  Count
# 942  1880     John      M   9655
# 943  1880  William      M   9532
# 944  1880    James      M   5927
# 945  1880  Charles      M   5348
# 946  1880   George      M   5126
# 947  1880    Frank      M   3242
# 948  1880   Joseph      M   2632
# 949  1880   Thomas      M   2534
# 950  1880    Henry      M   2444
# 951  1880   Robert      M   2415
# 952  1880   Edward      M   2364
# 953  1880    Harry      M   2152
# 954  1880   Walter      M   1755
# 955  1880   Arthur      M   1599
# 956  1880     Fred      M   1569
# 957  1880   Albert      M   1493
# 958  1880   Samuel      M   1024
# 959  1880    David      M    869
# 960  1880    Louis      M    828
# 961  1880      Joe      M    731

# %%
df_2018 = most_pop(2018, 'M', 20)
df_2018
# Out:
#          Year       Name Gender  Count
# 1943042  2018       Liam      M  19837
# 1943043  2018       Noah      M  18267
# 1943044  2018    William      M  14516
# 1943045  2018      James      M  13525
# 1943046  2018     Oliver      M  13389
# 1943047  2018   Benjamin      M  13381
# 1943048  2018     Elijah      M  12886
# 1943049  2018      Lucas      M  12585
# 1943050  2018      Mason      M  12435
# 1943051  2018      Logan      M  12352
# 1943052  2018  Alexander      M  11989
# 1943053  2018      Ethan      M  11854
# 1943054  2018      Jacob      M  11770
# 1943055  2018    Michael      M  11620
# 1943056  2018     Daniel      M  11173
# 1943057  2018      Henry      M  10649
# 1943058  2018    Jackson      M  10323
# 1943059  2018  Sebastian      M  10054
# 1943060  2018      Aiden      M   9979
# 1943061  2018    Matthew      M   9924

# %%
df_2018[['Name', 'Count']].merge(df_1880[['Name', 'Count']], how='inner', on='Name')
# Out:
#       Name  Count_x  Count_y
# 0  William    14516     9532
# 1    James    13525     5927
# 2    Henry    10649     2444

# %% [markdown]
# Find those __Evergreen Girl Names__ that are in __1880 and 2018__ among the most popular Girl Names (__Top 20__).

# %%
df_1880 = most_pop(1880, 'F', 20)
df_1880
# Out:
#     Year       Name Gender  Count
# 0   1880       Mary      F   7065
# 1   1880       Anna      F   2604
# 2   1880       Emma      F   2003
# 3   1880  Elizabeth      F   1939
# 4   1880     Minnie      F   1746
# 5   1880   Margaret      F   1578
# 6   1880        Ida      F   1472
# 7   1880      Alice      F   1414
# 8   1880     Bertha      F   1320
# 9   1880      Sarah      F   1288
# 10  1880      Annie      F   1258
# 11  1880      Clara      F   1226
# 12  1880       Ella      F   1156
# 13  1880   Florence      F   1063
# 14  1880       Cora      F   1045
# 15  1880     Martha      F   1040
# 16  1880      Laura      F   1012
# 17  1880     Nellie      F    995
# 18  1880      Grace      F    982
# 19  1880     Carrie      F    949

# %%
df_2018 = most_pop(2018, 'F', 20)
df_2018
# Out:
#          Year       Name Gender  Count
# 1925013  2018       Emma      F  18688
# 1925014  2018     Olivia      F  17921
# 1925015  2018        Ava      F  14924
# 1925016  2018   Isabella      F  14464
# 1925017  2018     Sophia      F  13928
# 1925018  2018  Charlotte      F  12940
# 1925019  2018        Mia      F  12642
# 1925020  2018     Amelia      F  12301
# 1925021  2018     Harper      F  10582
# 1925022  2018     Evelyn      F  10376
# 1925023  2018    Abigail      F   9796
# 1925024  2018      Emily      F   8656
# 1925025  2018  Elizabeth      F   8513
# 1925026  2018       Mila      F   8126
# 1925027  2018       Ella      F   8055
# 1925028  2018      Avery      F   8053
# 1925029  2018      Sofia      F   7621
# 1925030  2018     Camila      F   7473
# 1925031  2018       Aria      F   7394
# 1925032  2018   Scarlett      F   7182

# %%
df_2018[['Name', 'Count']].merge(df_1880[['Name', 'Count']], how='inner', on='Name')
# Out:
#         Name  Count_x  Count_y
# 0       Emma    18688     2003
# 1  Elizabeth     8513     1939
# 2       Ella     8055     1156

# %% [markdown]
# ## Advanced Data Aggregation

# %%
agg = df.groupby(['Name', 'Gender']).agg(Total=('Count', 'sum'), No_Year=('Year', 'count'), First_Year=('Year', lambda x: x.iloc[0]), Last_Year=('Year', lambda x: x.iloc[-1]), Max_Count=('Count', lambda x: max(x)))
agg
# Out:
#                 Total  No_Year  First_Year  Last_Year  Max_Count
# Name    Gender
# Aaban   M         114       11        2007       2018         16
# Aabha   F          35        5        2011       2016          9
# Aabid   M          16        3        2003       2018          6
# Aabidah F           5        1        2018       2018          5
# Aabir   M          10        2        2016       2018          5
# ...               ...      ...         ...        ...        ...
# Zyvion  M           5        1        2009       2009          5
# Zyvon   M           7        1        2015       2015          7
# Zyyanna F           6        1        2010       2010          6
# Zyyon   M           6        1        2014       2014          6
# Zzyzx   M          10        2        2010       2018          5
#
# [109173 rows x 5 columns]

# %%
def best_year(group):
    return group.nlargest(1, "Count").Year

# %%
best_y = df.groupby(['Name', 'Gender']).apply(best_year)

# %%
best_y
# Out:
# Name     Gender
# Aaban    M       1817711    2014
# Aabha    F       1803981    2014
# Aabid    M       1953741    2018
# Aabidah  F       1940601    2018
# Aabir    M       1890403    2016
#                             ...
# Zyvion   M       1658038    2009
# Zyvon    M       1856007    2015
# Zyyanna  F       1675008    2010
# Zyyon    M       1824324    2014
# Zzyzx    M       1692111    2010
# Name: Year, Length: 109173, dtype: int64

# %%
best_y.droplevel(-1)
# Out:
# Name     Gender
# Aaban    M         2014
# Aabha    F         2014
# Aabid    M         2018
# Aabidah  F         2018
# Aabir    M         2016
#                    ...
# Zyvion   M         2009
# Zyvon    M         2015
# Zyyanna  F         2010
# Zyyon    M         2014
# Zzyzx    M         2010
# Name: Year, Length: 109173, dtype: int64

# %%
agg['Best_Year'] = best_y.droplevel(-1)

# %%
agg
# Out:
#                 Total  No_Year  First_Year  Last_Year  Max_Count  Best_Year
# Name    Gender
# Aaban   M         114       11        2007       2018         16       2014
# Aabha   F          35        5        2011       2016          9       2014
# Aabid   M          16        3        2003       2018          6       2018
# Aabidah F           5        1        2018       2018          5       2018
# Aabir   M          10        2        2016       2018          5       2016
# ...               ...      ...         ...        ...        ...        ...
# Zyvion  M           5        1        2009       2009          5       2009
# Zyvon   M           7        1        2015       2015          7       2015
# Zyyanna F           6        1        2010       2010          6       2010
# Zyyon   M           6        1        2014       2014          6       2014
# Zzyzx   M          10        2        2010       2018          5       2010
#
# [109173 rows x 6 columns]

# %%
agg.reset_index(inplace=True)

# %%
agg
# Out:
#            Name Gender  Total  No_Year  First_Year  Last_Year  Max_Count  \
# 0         Aaban      M    114       11        2007       2018         16
# 1         Aabha      F     35        5        2011       2016          9
# 2         Aabid      M     16        3        2003       2018          6
# 3       Aabidah      F      5        1        2018       2018          5
# 4         Aabir      M     10        2        2016       2018          5
# ...         ...    ...    ...      ...         ...        ...        ...
# 109168   Zyvion      M      5        1        2009       2009          5
# 109169    Zyvon      M      7        1        2015       2015          7
# 109170  Zyyanna      F      6        1        2010       2010          6
# 109171    Zyyon      M      6        1        2014       2014          6
# 109172    Zzyzx      M     10        2        2010       2018          5
#
#         Best_Year
# 0            2014
# 1            2014
# 2            2018
# ...

# %% [markdown]
# __Filter__ agg for the combination (Mary, F)

# %%
agg[(agg.Name == "Mary") & (agg.Gender == "M")]
# Out:
#        Name Gender  Total  No_Year  First_Year  Last_Year  Max_Count  \
# 68680  Mary      M  15165      131        1880       2014        340
#
#        Best_Year
# 68680       1930

# %% [markdown]
# ## Most Popular Names of all Times

# %% [markdown]
# __Find__ the __10 most popular__ Male and Female Names of all Times (most popular in terms of total count).

# %%
agg.groupby("Gender").apply(lambda x: x.nlargest(10, "Total"))
# Out:
#                     Name Gender    Total  No_Year  First_Year  Last_Year  \
# Gender
# F      68679        Mary      F  4125675      139        1880       2018
#        30706   Elizabeth      F  1638349      139        1880       2018
#        79184    Patricia      F  1572016      135        1884       2018
#        46567    Jennifer      F  1467207      101        1916       2018
#        62973       Linda      F  1452668      139        1880       2018
#        11699     Barbara      F  1434397      139        1880       2018
#        67371    Margaret      F  1248985      139        1880       2018
#        94540       Susan      F  1121703      139        1880       2018
#        28575     Dorothy      F  1107635      139        1880       2018
#        87546       Sarah      F  1077746      139        1880       2018
# M      43582       James      M  5164280      139        1880       2018
#        48388        John      M  5124817      139        1880       2018
# ...

# %% [markdown]
# ## General Trends over time (1880 - 2018)

# %% [markdown]
# __Count__ the total number of __registered Babies per Year__ and visualize.

# %%
baby_per_y = df.groupby('Year').agg(Total=('Count', 'sum'))

# %%
import matplotlib.pyplot as plt

# %%
ax = baby_per_y.plot(kind='bar', figsize=(13, 10))

for i, t in enumerate(ax.get_xticklabels()):
    if (i % 5) != 0:
        t.set_visible(False)

plt.show()

# %% [markdown]
# __Count__ the total number of __Unique Names per Year__ and visualize.

# %%
name_per_y = df.groupby('Year').agg(Total=('Name', 'count'))

# %%
ax = name_per_y.plot(kind='bar', figsize=(13, 10))

for i, t in enumerate(ax.get_xticklabels()):
    if (i % 5) != 0:
        t.set_visible(False)

plt.show()

# %% [markdown]
# ## Creating the Features "Popularity" and "Rank"

# %% [markdown]
# __Add__ the column __"Popularity"__ to df: <br>
# - Popularity in __babies per million__ (example: assume 2,000,000 registered Girl Names in 1950, thereof 100,000 Maries -> Popularity Score in 1950 for (Mary, F) is 100,000 / 2,000,000 * 1,000,000 = 50,000 per million.)

# %% [markdown]
# __Add__ the column __"Rank"__ to df: <br>
# - Rank (example: assume Mary is the most popular Girl Name in 1950 -> Rank 1 for (Mary, F) in 1950.

# %%
df['Popularity'] = df['Count'] / df.groupby(["Year", "Gender"]).Count.transform("sum") * 1e6
df['Popularity'] = df['Popularity'].astype(int)

# %%
df
# Out:
#          Year       Name Gender  Count  Popularity
# 0        1880       Mary      F   7065       77642
# 1        1880       Anna      F   2604       28617
# 2        1880       Emma      F   2003       22012
# 3        1880  Elizabeth      F   1939       21309
# 4        1880     Minnie      F   1746       19188
# ...       ...        ...    ...    ...         ...
# 1957041  2018      Zylas      M      5           2
# 1957042  2018      Zyran      M      5           2
# 1957043  2018      Zyrie      M      5           2
# 1957044  2018      Zyron      M      5           2
# 1957045  2018      Zzyzx      M      5           2
#
# [1957046 rows x 5 columns]

# %%
df['Year']
# Out:
# 0          1880
# 1          1880
# 2          1880
# 3          1880
# 4          1880
#            ...
# 1957041    2018
# 1957042    2018
# 1957043    2018
# 1957044    2018
# 1957045    2018
# Name: Year, Length: 1957046, dtype: int64

# %%
df
# Out:
#          Year       Name Gender  Count  Popularity
# 0        1880       Mary      F   7065       77642
# 1        1880       Anna      F   2604       28617
# 2        1880       Emma      F   2003       22012
# 3        1880  Elizabeth      F   1939       21309
# 4        1880     Minnie      F   1746       19188
# ...       ...        ...    ...    ...         ...
# 1957041  2018      Zylas      M      5           2
# 1957042  2018      Zyran      M      5           2
# 1957043  2018      Zyrie      M      5           2
# 1957044  2018      Zyron      M      5           2
# 1957045  2018      Zzyzx      M      5           2
#
# [1957046 rows x 5 columns]

# %%
df['Rank'] = df.groupby(['Year', 'Gender'])['Count'].rank(ascending=False)

# %%
df
# Out:
#          Year       Name Gender  Count  Popularity     Rank
# 0        1880       Mary      F   7065       77642      1.0
# 1        1880       Anna      F   2604       28617      2.0
# 2        1880       Emma      F   2003       22012      3.0
# 3        1880  Elizabeth      F   1939       21309      4.0
# 4        1880     Minnie      F   1746       19188      5.0
# ...       ...        ...    ...    ...         ...      ...
# 1957041  2018      Zylas      M      5           2  13042.0
# 1957042  2018      Zyran      M      5           2  13042.0
# 1957043  2018      Zyrie      M      5           2  13042.0
# 1957044  2018      Zyron      M      5           2  13042.0
# 1957045  2018      Zzyzx      M      5           2  13042.0
#
# [1957046 rows x 6 columns]

# %% [markdown]
# ## Visualizing Name Trends over Time

# %% [markdown]
#  __Visualize__ Popularity and Rank over time (see example below).

# %%
df1 = df[df['Name'] == 'Josh']
ax = df1.plot(x='Year', y='Rank', kind='line', figsize=(13, 10), color='Red', use_index=False)
# ax2 = ax.twinx()
df1.plot(x='Year', y='Popularity', kind='bar', ax=ax, secondary_y=True, color='Blue')

for i, t in enumerate(ax.get_xticklabels()):
    if (i % 10) != 0:
        t.set_visible(False)

plt.show()

# %%
def evergreen_names(gender):
    df_2018 = most_pop(2018, gender, 20)
    df_1880 = most_pop(1880, gender, 20)
    return df_2018[['Name', 'Count']].merge(df_1880[['Name', 'Count']], how='inner', on='Name')
    
f_evergreens = evergreen_names('F')['Name']
m_evergreens = evergreen_names('M')['Name']

# %%
f_evergreens
# Out:
# 0         Emma
# 1    Elizabeth
# 2         Ella
# Name: Name, dtype: object

# %%
m_evergreens
# Out:
# 0    William
# 1      James
# 2      Henry
# Name: Name, dtype: object

# %%
# def name_over_time(name):
#     df1 = df[df['Name'] == name]
#     ax = df1.plot(x='Year', y='Popularity', kind='bar', figsize=(13, 10), color='Blue', use_index=False, title=name)
#     ax2 = ax.twinx()
#     df1.plot(x='Year', y='Rank', kind='line', ax=ax2, secondary_y=True, color='Red')

#     for i, t in enumerate(ax.get_xticklabels()):
#         if (i % 10) != 0:
#             t.set_visible(False)
            
#     ax.set_xlabel("Year")
#     ax.set_ylabel("Babies per million")
#     ax2.set_ylabel("Rank")
    
#     plt.show()

# %%
def plot_name(name):
    data = df[(df['Name'] == name) & (df['Gender'] == 'F')]
    
    fig, ax1 = plt.subplots(figsize = (12, 8))
    ax1.bar(data['Year'], height= data['Popularity'], label = 'Popularity')
    ax2 = ax1.twinx()
    ax2.plot(data['Year'], data.Rank, color ="red", label = "Rank")
    ax1.set_xlabel("Year", fontsize = 15)
    ax1.set_ylabel('Popularity', fontsize = 15)
    ax2.set_ylabel("Rank", fontsize = 15)
    ax1.set_title(name, fontsize = 18)
    ax1.tick_params(labelsize = 12)
    ax2.tick_params(labelsize = 12)
    ax1.legend(loc = 2, fontsize = 15)
    ax2.legend(loc = 1, fontsize = 15)
    plt.show()

# %%
plot_name(f_evergreens[0])

# %%
plot_name(f_evergreens[1])

# %%
plot_name(f_evergreens[2])

# %%
plot_name(m_evergreens[0])

# %%
plot_name(m_evergreens[1])

# %%
plot_name(m_evergreens[2])

# %% [markdown]
# # Why does a Name´s Popularity suddenly change? (Part 1)

# %% [markdown]
# __Add__ the additional columns __"Pop_lag1"__ (Popularity one year ago) and __"Pop_diff"__ (change in popularity from previous year to this year) to df.

# %%
df['Pop_lag1'] = df['Popularity'].shift(1)

# %%
df['Pop_diff'] = df['Popularity'] - df['Pop_lag1']

# %% [markdown]
# __Create__ df2 starting with the __year 1900__ (from 1900 till today).

# %%
df2 = df[df['Year'] >= 1900]

# %% [markdown]
# __Filter__ df2 and find the __20 largest values__ in "Pop_diff" (get complete rows).

# %%
largest_diffs = df2.nlargest(20, 'Pop_diff')
largest_diffs
# Out:
#         Year  Name Gender  Count  Popularity  Rank  Pop_lag1  Pop_diff
# 54489   1900  John      M   9829       65317   1.0      16.0   65301.0
# 57938   1901  John      M   6900       64807   1.0      20.0   64787.0
# 61190   1902  John      M   7907       64463   1.0      18.0   64445.0
# 64593   1903  John      M   7608       63808   1.0      19.0   63789.0
# 68064   1904  John      M   8108       63281   1.0      18.0   63263.0
# 75334   1906  John      M   8265       62069   1.0      16.0   62053.0
# 79146   1907  John      M   8983       61180   1.0      15.0   61165.0
# 71693   1905  John      M   8060       60917   1.0      17.0   60900.0
# 83129   1908  John      M   9342       60529   1.0      14.0   60515.0
# 191066  1922  Mary      F  72173       60094   1.0       4.0   60090.0
# 180209  1921  Mary      F  73985       60001   1.0       4.0   59997.0
# 111755  1914  Mary      F  45345       59540   1.0       9.0   59531.0
# ...

# %% [markdown]
# __Create__ the popularity/rank plot for the Names filtered

# %%
for name in largest_diffs['Name'].drop_duplicates():
    plot_name(name)

# %% [markdown]
# __Search__ the Web for the Names __"Linda"__, __"Shirley"__ and __"Jason"__ and __find out__ why the popularity suddenly changed/spiked.

# %% [markdown]
# ## Most Popular Unisex Names

# %% [markdown]
# __Find__ the most popular __Unisex Names__ of all times. (Unisex names are names given to Boys and Girls).

# %%
unisex = df.groupby(["Name", "Gender"]).Count.sum().unstack()
unisex
# Out:
# Gender      F      M
# Name
# Aaban     NaN  114.0
# Aabha    35.0    NaN
# Aabid     NaN   16.0
# Aabidah   5.0    NaN
# Aabir     NaN   10.0
# ...       ...    ...
# Zyvion    NaN    5.0
# Zyvon     NaN    7.0
# Zyyanna   6.0    NaN
# Zyyon     NaN    6.0
# Zzyzx     NaN   10.0
#
# [98400 rows x 2 columns]

# %%
unisex.dropna(inplace=True)
unisex
# Out:
# Gender         F       M
# Name
# Aaden        5.0  4828.0
# Aadi        16.0   851.0
# Aadyn       16.0   516.0
# Aalijah    149.0   212.0
# Aaliyah  87442.0    96.0
# ...          ...     ...
# Zyion      168.0   918.0
# Zyon       620.0  2638.0
# Zyonn        5.0    40.0
# Zyree       16.0    94.0
# Zyrie       19.0    16.0
#
# [10773 rows x 2 columns]

# %%
unisex_names = unisex.min(axis = 1).sort_values(ascending = False).index
unisex_names
# Out:
# Index(['Willie', 'Jordan', 'Leslie', 'Taylor', 'Jessie', 'Terry', 'Angel',
#        'Riley', 'Jamie', 'Kelly',
#        ...
#        'Hanalei', 'Handy', 'Haniel', 'Hans', 'Hansel', 'Hany', 'Hao', 'Haram',
#        'Harjap', 'Aaden'],
#       dtype='object', name='Name', length=10773)
